# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import theano
rain = pd.read_csv('/home/prasad/Documents/Machine Learning/Datasets/rain.csv')
rain.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-fa60575c074c> in <module>
#       3 import seaborn as sns
#       4 import numpy as np
# ----> 5 import theano
#       6 rain = pd.read_csv('/home/prasad/Documents/Machine Learning/Datasets/rain.csv')
#       7 rain.head()
#
# ModuleNotFoundError: No module named 'theano'

# %%
rain['Location'].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
rain['Location'].unique().tolist()
# Out:
# ['Albury',
#  'BadgerysCreek',
#  'Cobar',
#  'CoffsHarbour',
#  'Moree',
#  'Newcastle',
#  'NorahHead',
#  'NorfolkIsland',
#  'Penrith',
#  'Richmond',
#  'Sydney',
#  'SydneyAirport',
#  'WaggaWagga',
#  'Williamtown',
#  'Wollongong',
#  'Canberra',
#  'Tuggeranong',
#  'MountGinini',
#  'Ballarat',
#  'Bendigo',
#  'Sale',
#  'MelbourneAirport',
#  'Melbourne',
#  'Mildura',
#  'Nhil',
#  'Portland',
#  'Watsonia',
#  'Dartmoor',
#  'Brisbane',
#  'Cairns',
#  'GoldCoast',
#  'Townsville',
#  'Adelaide',
#  'MountGambier',
#  'Nuriootpa',
#  'Woomera',
#  'Albany',
#  'Witchcliffe',
#  'PearceRAAF',
#  'PerthAirport',
#  'Perth',
#  'SalmonGums',
#  'Walpole',
#  'Hobart',
#  'Launceston',
#  'AliceSprings',
#  'Darwin',
#  'Katherine',
#  'Uluru']

# %%
rain['Evaporation'].unique()
# Out:
# array([     nan, 1.20e+01, 1.48e+01, 1.26e+01, 1.08e+01, 1.14e+01,
#        1.12e+01, 1.30e+01, 9.80e+00, 1.46e+01, 1.10e+01, 1.28e+01,
#        1.38e+01, 1.64e+01, 1.74e+01, 1.60e+01, 1.36e+01, 8.00e+00,
#        8.20e+00, 8.60e+00, 1.42e+01, 1.58e+01, 1.62e+01, 1.34e+01,
#        1.44e+01, 1.18e+01, 1.56e+01, 1.52e+01, 1.16e+01, 9.60e+00,
#        6.60e+00, 6.00e-01, 6.00e+00, 3.00e+00, 2.00e+00, 5.20e+00,
#        9.00e+00, 1.02e+01, 1.00e+01, 7.40e+00, 8.40e+00, 9.20e+00,
#        9.40e+00, 1.24e+01, 1.04e+01, 7.20e+00, 6.80e+00, 7.60e+00,
#        4.40e+00, 6.40e+00, 7.80e+00, 7.00e+00, 8.80e+00, 6.20e+00,
#        5.80e+00, 2.00e-01, 2.40e+00, 1.80e+00, 2.20e+00, 2.80e+00,
#        5.00e+00, 5.60e+00, 4.80e+00, 4.20e+00, 4.00e+00, 3.20e+00,
#        4.60e+00, 3.40e+00, 3.60e+00, 0.00e+00, 1.40e+00, 3.80e+00,
#        8.00e-01, 2.60e+00, 1.60e+00, 1.20e+00, 1.00e+00, 5.40e+00,
#        1.06e+01, 1.68e+01, 1.70e+01, 2.02e+01, 1.40e+01, 1.72e+01,
# ...

# %%
sns.heatmap(rain.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
rain.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  141556.000000  141871.000000  140787.000000  81350.000000
# mean       12.186400      23.226784       2.349974      5.469824
# std         6.403283       7.117618       8.465173      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  74377.000000  132923.000000  140845.000000  139563.000000
# mean       7.624853      39.984292      14.001988      18.637576
# std        3.781525      13.588801       8.893337       8.803345
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
rain['Evaporation'] = rain['Evaporation'].replace(np.nan, 5.469)

# %%
rain.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6        5.469       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0        5.469       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0        5.469       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0        5.469       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0        5.469       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
# 2         WSW           46.0          W      ...             30.0
# 3          NE           24.0         SE      ...             16.0
# 4           W           41.0        ENE      ...             33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.heatmap(rain.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
rain.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6        5.469       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0        5.469       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0        5.469       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0        5.469       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0        5.469       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
# 2         WSW           46.0          W      ...             30.0
# 3          NE           24.0         SE      ...             16.0
# 4           W           41.0        ENE      ...             33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.heatmap(rain.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
rain.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
rain['Sunshine'] = rain['Sunshine'].replace(np.nan, 7.624)

# %%
rain['Cloud9am'] = rain['Cloud9am'].replace(np.nan, 4.437)

# %%
rain['Cloud3pm'] = rain['Cloud3pm'].replace(np.nan , 4.503)

# %%
sns.heatmap(rain.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
rain
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6        5.469
# 1       2008-12-02   Albury      7.4     25.1       0.0        5.469
# 2       2008-12-03   Albury     12.9     25.7       0.0        5.469
# 3       2008-12-04   Albury      9.2     28.0       0.0        5.469
# 4       2008-12-05   Albury     17.5     32.3       1.0        5.469
# 5       2008-12-06   Albury     14.6     29.7       0.2        5.469
# 6       2008-12-07   Albury     14.3     25.0       0.0        5.469
# 7       2008-12-08   Albury      7.7     26.7       0.0        5.469
# 8       2008-12-09   Albury      9.7     31.9       0.0        5.469
# 9       2008-12-10   Albury     13.1     30.1       1.4        5.469
# 10      2008-12-11   Albury     13.4     30.4       0.0        5.469
# 11      2008-12-12   Albury     15.9     21.7       2.2        5.469
# 12      2008-12-13   Albury     15.9     18.6      15.6        5.469
# ...

# %%
rain.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6        5.469     7.624
# 1  2008-12-02   Albury      7.4     25.1       0.0        5.469     7.624
# 2  2008-12-03   Albury     12.9     25.7       0.0        5.469     7.624
# 3  2008-12-04   Albury      9.2     28.0       0.0        5.469     7.624
# 4  2008-12-05   Albury     17.5     32.3       1.0        5.469     7.624
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
# 2         WSW           46.0          W      ...             30.0
# 3          NE           24.0         SE      ...             16.0
# 4           W           41.0        ENE      ...             33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
rain2 = rain.dropna()

# %%
rain2.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6        5.469     7.624
# 1  2008-12-02   Albury      7.4     25.1       0.0        5.469     7.624
# 2  2008-12-03   Albury     12.9     25.7       0.0        5.469     7.624
# 3  2008-12-04   Albury      9.2     28.0       0.0        5.469     7.624
# 4  2008-12-05   Albury     17.5     32.3       1.0        5.469     7.624
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
# 2         WSW           46.0          W      ...             30.0
# 3          NE           24.0         SE      ...             16.0
# 4           W           41.0        ENE      ...             33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.heatmap(rain2.isnull(),cbar = True,yticklabels=False,cmap='viridis')
